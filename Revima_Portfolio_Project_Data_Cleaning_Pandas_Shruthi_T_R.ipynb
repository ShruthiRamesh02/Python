# %% [markdown]
# <a href="https://colab.research.google.com/github/ShruthiRamesh02/Python/blob/main/Revima_Portfolio_Project_Data_Cleaning_Pandas_Shruthi_T_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7d303aff-6fe5-4e65-a1db-2b83c1b435ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d303aff-6fe5-4e65-a1db-2b83c1b435ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Revima_Portfolio Project_Shruthi T R (1).xlsx')
df
# Out:
#          Project  Work Order  Order No  Position Part         Part No  \
# 0     B000000050      1375.0     80472     082-215-66       201056906
# 1     B000000050      1703.0     94869     082-215-98       201173700
# 2     B000000050      1717.0     95499  082-225-24-01  D3215303000800
# 3     B000000050      1741.0     94939     082-120-09        D65566-1
# 4     B000000050      1742.0     94956     082-120-09        D65566-1
# ...          ...         ...       ...            ...             ...
# 2675  C000000027      1559.0     88067            NaN      161A2318-1
# 2676  C000000027      1561.0     88293            NaN      161A7118-1
# 2677  C000000027      1561.0     87681            NaN      161A7302-1
# 2678  C000000027      1561.0     88280            NaN      161A7114-2
# 2679  C000000027      1561.0     87771            NaN      161A7305-1
#
#              Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# ...

# %%
pd.set_option('display.float_format',lambda x:'%.2f'% x)
df
# Out:
#          Project  Work Order  Order No  Position Part         Part No  \
# 0     B000000050     1375.00     80472     082-215-66       201056906
# 1     B000000050     1703.00     94869     082-215-98       201173700
# 2     B000000050     1717.00     95499  082-225-24-01  D3215303000800
# 3     B000000050     1741.00     94939     082-120-09        D65566-1
# 4     B000000050     1742.00     94956     082-120-09        D65566-1
# ...          ...         ...       ...            ...             ...
# 2675  C000000027     1559.00     88067            NaN      161A2318-1
# 2676  C000000027     1561.00     88293            NaN      161A7118-1
# 2677  C000000027     1561.00     87681            NaN      161A7302-1
# 2678  C000000027     1561.00     88280            NaN      161A7114-2
# 2679  C000000027     1561.00     87771            NaN      161A7305-1
#
#              Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#          Project  Work Order  Order No  Position Part         Part No  \
# 0     B000000050     1375.00     80472     082-215-66       201056906
# 1     B000000050     1703.00     94869     082-215-98       201173700
# 2     B000000050     1717.00     95499  082-225-24-01  D3215303000800
# 3     B000000050     1741.00     94939     082-120-09        D65566-1
# 4     B000000050     1742.00     94956     082-120-09        D65566-1
# ...          ...         ...       ...            ...             ...
# 2675  C000000027     1559.00     88067            NaN      161A2318-1
# 2676  C000000027     1561.00     88293            NaN      161A7118-1
# 2677  C000000027     1561.00     87681            NaN      161A7302-1
# 2678  C000000027     1561.00     88280            NaN      161A7114-2
# 2679  C000000027     1561.00     87771            NaN      161A7305-1
#
#              Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# ...

# %%
df=df.drop(columns="Release No")
df
# Out:
#          Project  Work Order  Order No  Position Part         Part No  \
# 0     B000000050     1375.00     80472     082-215-66       201056906
# 1     B000000050     1703.00     94869     082-215-98       201173700
# 2     B000000050     1717.00     95499  082-225-24-01  D3215303000800
# 3     B000000050     1741.00     94939     082-120-09        D65566-1
# 4     B000000050     1742.00     94956     082-120-09        D65566-1
# ...          ...         ...       ...            ...             ...
# 2675  C000000027     1559.00     88067            NaN      161A2318-1
# 2676  C000000027     1561.00     88293            NaN      161A7118-1
# 2677  C000000027     1561.00     87681            NaN      161A7302-1
# 2678  C000000027     1561.00     88280            NaN      161A7114-2
# 2679  C000000027     1561.00     87771            NaN      161A7305-1
#
#              Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# ...

# %%
df=df.drop_duplicates('Tardy')
df
# Out:
#          Project  Work Order  Order No Position Part     Part No  \
# 0     B000000050     1375.00     80472    082-215-66   201056906
# 4     B000000050     1742.00     94956    082-120-09    D65566-1
# 1861  B000000050     1704.00     93784    082-120-34  082-120-34
#
#            Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# 0          INSERT, THREADED          Repair         1                CADSTR
# 4     PIN,TORQUE LINK HINGE          Repair         1                BRUCAD
# 1861              CAM,LOWER     Disposition         1                INSPEC
#
#      Standard Op Description Actual  ... MRB Exists Control Plan No  \
# 0                 Cadmium Stripping  ...       0.00             NaN
# 4             Brush Cadmium Plating  ...       0.00             NaN
# 1861                     Inspection  ...        NaN             NaN
#
#      Ctrl Plan Rev No Control Plan Template ID  \
# 0                 NaN                      NaN
# ...

# %%
df=df.drop(columns="Tardy")
df
# Out:
#          Project  Work Order  Order No Position Part     Part No  \
# 0     B000000050     1375.00     80472    082-215-66   201056906
# 4     B000000050     1742.00     94956    082-120-09    D65566-1
# 1861  B000000050     1704.00     93784    082-120-34  082-120-34
#
#            Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# 0          INSERT, THREADED          Repair         1                CADSTR
# 4     PIN,TORQUE LINK HINGE          Repair         1                BRUCAD
# 1861              CAM,LOWER     Disposition         1                INSPEC
#
#      Standard Op Description Actual  ... Enable Rev/Alt to be Changed  \
# 0                 Cadmium Stripping  ...                         0.00
# 4             Brush Cadmium Plating  ...                         0.00
# 1861                     Inspection  ...                          NaN
#
#      MRB Exists Control Plan No Ctrl Plan Rev No Control Plan Template ID  \
# ...

# %%
df
# Out:
#          Project  Work Order  Order No Position Part     Part No  \
# 0     B000000050     1375.00     80472    082-215-66   201056906
# 4     B000000050     1742.00     94956    082-120-09    D65566-1
# 1861  B000000050     1704.00     93784    082-120-34  082-120-34
#
#            Part Description Shop Order Type  Lot Size Standard Op ID Actual  \
# 0          INSERT, THREADED          Repair         1                CADSTR
# 4     PIN,TORQUE LINK HINGE          Repair         1                BRUCAD
# 1861              CAM,LOWER     Disposition         1                INSPEC
#
#      Standard Op Description Actual  ... Enable Rev/Alt to be Changed  \
# 0                 Cadmium Stripping  ...                         0.00
# 4             Brush Cadmium Plating  ...                         0.00
# 1861                     Inspection  ...                          NaN
#
#      MRB Exists Control Plan No Ctrl Plan Rev No Control Plan Template ID  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr(), annot = True)
plt.rcParams['figure.figsize']=(20,7)
plt.show
# Out:
# <ipython-input-35-a5bdf17d851b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tips = sns.load_dataset('tips')
sns.pairplot(tips,hue='smoker');

# %%
corr_matrix=tips.corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <ipython-input-38-002c9e329910>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=tips.corr()
# <Axes: >

# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %% [markdown]
# # New section
